# %% [markdown]
# ## Метод groupby()

# %%
import pandas as pd

melb_data = pd.read_csv('data/melb_data_fe.csv', sep=',')
melb_df = melb_data.copy()

# %% [markdown]
# ### Основные параметры метода groupby()
#
# - by — имя или список имён столбцов, по которым производится группировка.
# - axis — ось, по которой производится группировка (0 — строки, 1 — столбцы). По умолчанию группировка производится по строкам.
# - as_index — добавляется ли дополнительный индекс к таблице. По умолчанию установлен на True.

# %% [markdown]
# Группировка данных по одному критерию с одной агрегацией

# %%
melb_df.groupby(by='BuildingArea').mean(numeric_only=True)
# Out:
#                  Rooms         Price   Distance     Postcode   Bedroom  \
# BuildingArea
# 0.0           3.529412  1.448853e+06  11.611765  3118.470588  3.529412
# 1.0           2.636364  1.057176e+06   8.945455  3100.636364  2.636364
# 2.0           2.000000  7.862812e+05   6.650000  3086.500000  2.125000
# 3.0           3.000000  8.613500e+05   9.720000  3094.750000  3.000000
# 4.0           4.000000  9.642500e+05  11.500000  3107.750000  4.000000
# ...                ...           ...        ...          ...       ...
# 1561.0        2.000000  7.410000e+05   8.500000  3185.000000  3.000000
# 3112.0        5.000000  2.608000e+06   7.800000  3124.000000  5.000000
# 3558.0        2.000000  9.300000e+05   3.500000  3068.000000  2.000000
# 6791.0        4.000000  1.280000e+06  11.800000  3105.000000  4.000000
# 44515.0       5.000000  1.355000e+06  48.100000  3438.000000  5.000000
#
#               Bathroom       Car      Landsize  Lattitude  Longtitude  \
# BuildingArea
# 0.0           1.823529  1.823529    517.941176 -37.785674  145.038872
# 1.0           1.636364  1.363636    460.545455 -37.797854  145.048573
# 2.0           1.312500  1.187500    141.937500 -37.802686  144.972602
# 3.0           1.700000  1.650000    154.550000 -37.809370  144.985702
# 4.0           2.250000  1.750000    928.250000 -37.837717  144.965737
# ...                ...       ...           ...        ...         ...
# 1561.0        1.000000  1.000000      0.000000 -37.882900  145.003300
# 3112.0        2.000000  4.000000    730.000000 -37.842400  145.063900
# 3558.0        3.000000  0.000000   2778.000000 -37.790300  144.985900
# 6791.0        1.000000  2.000000    732.000000 -37.761500  145.089700
# 44515.0       3.000000  5.000000  44500.000000 -37.453920  144.588640
#
#               Propertycount  MeanRoomsSquare  AreaRatio  MonthSale  \
# BuildingArea
# 0.0             7997.117647         0.000000  -1.000000   6.647059
# 1.0            11436.727273         0.174170  -0.631024   7.636364
# 2.0             7415.250000         0.372024  -0.478215   6.375000
# 3.0             7807.650000         0.391071  -0.764582   6.900000
# 4.0             3093.000000         0.390909  -0.981368   6.000000
# ...                     ...              ...        ...        ...
# 1561.0          4898.000000       260.166667   1.000000   4.000000
# 3112.0          8920.000000       259.333333   0.619990  10.000000
# 3558.0          6244.000000       508.285714   0.123106   3.000000
# 6791.0          4480.000000       754.555556   0.805397  11.000000
# 44515.0          849.000000      3424.230769   0.000169   9.000000
#
#               AgeBuilding  WeekdaySale   Weekend
# BuildingArea
# 0.0             41.470588     4.235294  0.705882
# 1.0             38.090909     5.272727  0.909091
# 2.0             47.187500     4.500000  0.812500
# 3.0             41.650000     4.200000  0.600000
# 4.0             35.500000     3.500000  0.500000
# ...                   ...          ...       ...
# 1561.0          50.000000     5.000000  1.000000
# 3112.0          96.000000     5.000000  1.000000
# 3558.0          46.000000     2.000000  0.000000
# 6791.0          47.000000     4.000000  0.000000
# 44515.0         47.000000     5.000000  1.000000
#
# [602 rows x 17 columns]

# %% [markdown]
# Обратите внимание на структуру получившейся таблицы: теперь на месте индексов стоят значения типа объекта недвижимости Type (house, townhouse, unit).
#
# Примечание. Если мы хотим видеть тип объекта в качестве отдельного столбца таблицы, мы можем выставить параметр as_index на False:

# %% [markdown]
# Как правило, нам не нужна информация обо всех столбцах, поэтому агрегирующие методы можно применять только к интересующему нас столбцу. Например, давайте сравним средние цены на объекты в зависимости от их типа:

# %%
print(melb_df.groupby('Type')['Price'].mean())
# Out:
# Type
# house        1.242665e+06
# townhouse    9.337351e+05
# unit         6.051275e+05
# Name: Price, dtype: float64

# %% [markdown]
# Теперь давайте выясним, какие регионы (Regionname) наиболее удалены от центра Мельбурна.
