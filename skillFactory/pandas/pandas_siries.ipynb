# %% [markdown]
# Вы работаете аналитиком в компании ScienceYou. Ваша задача — проанализировать чистую прибыль.
#
# Доходы (income), расходы (expenses) и годы (years), соответствующие им, предоставлены вам в виде списков.
#
# Например:
# ```
# income = [478, 512, 196]
# expenses = [156, 130, 270]
# years = [2018, 2019, 2020]
# ```
#
# Создайте функцию create_companyDF(income, expenses, years), которая возвращает DataFrame, составленный из входных данных со столбцами Income и Expenses и индексами, соответствующими годам рассматриваемого периода.
#
# Пример такого DataFrame представлен ниже.
# ```
#     Income  Expenses
# 2018    478     156
# 2019    512     130
# 2020    196     270
# ```
# Также напишите функцию get_profit(df, year), которая возвращает разницу между доходом и расходом, записанными в таблице df, за год year.
#
# Примечание. Если информация за запрашиваемый год не указана в вашей таблице, вам необходимо вернуть None.

# %%
import pandas as pd 

income = [478, 512, 196]
expenses = [156, 130, 270]
years = [2018, 2019, 2020]

def create_companyDF(income, expenses, years):
    company_df = pd.DataFrame(
        data = {
            'Income': income,
            'Expenses': expenses},
        index = years)
    return company_df
df = create_companyDF(income, expenses, years)

def get_profit(df, year):
    try:
      return df.loc[year, 'Income'] - df.loc[year, 'Expenses']
    except KeyError:
       None

print(get_profit(df, 2018))
# Out:
# 322

# %% [markdown]
# Заранее создадим папку data в директории, где лежит наш ноутбук. Теперь давайте сохраним наш DataFrame с информацией о странах в csv-файл countries.csv и положим файл в папку data. При этом укажем, что разделителем в нашем файле будет являться символ ';', а также то, что нам не нужен дополнительный столбец с индексами строк:

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'area': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.to_csv('data/countries.csv', index=False, sep=';')

# %% [markdown]
# Убедимся, что сохранённый нами ранее файл создался верно. Для этого прочитаем его в переменную countries_data и выведем её на экран. Не забудем также о том, что мы использовали в качестве разделителя ';':

# %%
countries_data = pd.read_csv('data/countries.csv', sep=';')
display(countries_data)
# Out:
#      country  population      area
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902

# %%
melb_data = pd.read_csv('data/melb_data.csv', sep=',')
result = melb_data.isna().sum()

melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')

display(melb_data.describe(include=object))
# Out:
#            Suburb       Address   Type Method SellerG        Date CouncilArea  \
# count       13580         13580  13580  13580   13580       13580       12211
# unique        314         13378      3      5     268          58          33
# top     Reservoir  5 Charles St      h      S  Nelson  27/05/2017    Moreland
# freq          359             3   9449   9022    1565         473        1163
#
#                    Regionname         Coordinates
# count                   13580               13580
# unique                      8               13097
# top     Southern Metropolitan  -37.8361, 144.9966
# freq                     4695                  12

# %% [markdown]
# Сколько процентов от общего количества домов составляют таунхаусы (тип объекта — t)?
# Ответ округлите до целого числа. Не указывайте знак %.

# %%
display(melb_data.describe(include=object))
display(round(melb_data['Type']== 't').mean() * 100)
# Out:
#            Suburb       Address   Type Method SellerG        Date CouncilArea  \
# count       13580         13580  13580  13580   13580       13580       12211
# unique        314         13378      3      5     268          58          33
# top     Reservoir  5 Charles St      h      S  Nelson  27/05/2017    Moreland
# freq          359             3   9449   9022    1565         473        1163
#
#                    Regionname         Coordinates
# count                   13580               13580
# unique                      8               13097
# top     Southern Metropolitan  -37.8361, 144.9966
# freq                     4695                  12
# np.float64(8.203240058910161)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Для каких столбцов метод std() выполнится с ошибкой?

# %%
import pandas as pd

melb_data = pd.read_csv('data/melb_data.csv', sep=',')


# Застройщик нелоьсон цена больше 3 000 000
#melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] > 3000000)].shape[0]

# Мин цена за площадь без здания
#melb_data[melb_data['BuildingArea'] == 0]['Price'].min()

# среднее отклонение по длине дистанции от дома к центру
#print(melb_data['Distance'].std())

# среднее колличество ванн
#print(melb_data['Bedroom'].mode())

# среднее отклонение от цены в %
#percentage_deviation = round((melb_data['BuildingArea'].median() - melb_data['BuildingArea'].mean()) / melb_data['BuildingArea'].mean() * 100)
#print(percentage_deviation)

# средня цена меньше милиона и комнать больше 5 либо здание моложе 2015 года

#price_filter = melb_data['Price'] < 1000000
#rooms_filter = melb_data['Rooms'] > 5
#years_filter = melb_data['YearBuilt'] > 2015

#price_df = melb_data[price_filter & (rooms_filter | years_filter)]

#print(round(price_df['Price'].mean()))

# В каком районе Мельбурна чаще всего продаются виллы и коттеджи (тип здания — h) с ценой меньше трёх миллионов?


print(melb_data[(melb_data['Type'] == 'h') & (melb_data['Price'] < 3000000)]['Regionname'].mode())
display(melb_data)
# Out:
# 0    Northern Metropolitan
# Name: Regionname, dtype: object
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# ...

# %% [markdown]
# Стандартное отклонение (std) — это мера того, насколько значения разбросаны вокруг среднего.
#
# Проще:
#
# 👉 показывает насколько данные “гуляют” от среднего значения.v
#
# Пример
#
# Есть числа:
# ```
# [10, 10, 10, 10]
# ```
# Среднее = 10
# Все значения одинаковые → разброса нет
#
# std = 0
#
# Теперь:
# ```
# [5, 10, 15]
# ```
# Среднее = 10
# Но значения отклоняются
#
# → стандартное отклонение будет больше 0.

# %%
import pandas as pd

mode = pd.DataFrame({
   'numbers' : [1, 2, 4, 2, 3, 2, 1, 5, 6],
   
})

print(mode.mode())
# Out:
#    numbers
# 0        2
