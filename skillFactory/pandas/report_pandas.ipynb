# %% [markdown]
# Информация о столбцах таблицы:
#
# - gender — пол;
# - race/ethnicity — раса/этническая принадлежность;
# - parental level of education — уровень образования родителей;
# - lunch — какие обеды получал студент во время обучения (standard — платный, free/reduced — бесплатный);
# - test preparation course — посещал ли студент курсы подготовки к экзаменам (none — не посещал, completed — посещал);
# - math score, reading score, writing score — баллы по математике, чтению и письму по сто балльной шкале.

# %%
import pandas as pd
student_data = pd.read_csv('data/students_performance.csv', sep=',')

display(student_data)

# Данные о скольких студентах содержатся в таблице?

# Каков балл по письму у студента под индексом 155?
#display(student_data.iloc[155])

# Сколько суммарно пропущенных значений в таблице?
#student_skip_rows = student_data.isna().sum()
#print(student_skip_rows)

# Сколько столбцов в таблице имеет тип данных object?
#student_object_type = student_data.select_dtypes('object').shape[1]
#print(student_object_type)
#print(student_data.info())

# Каков у студентов средний балл по математике?
# mean_math_score = student_data['math score'].mean()
#rint(mean_math_score)
   
# Какая расовая группа является самой крупной в учебном заведении?
#print(student_data['race/ethnicity'].mode())

# Каков средний балл по чтению у студентов, которые посещали курсы подготовки к экзаменам?
#mean_score = student_data[(student_data['test preparation course'] == 'completed')]['reading score'].mean()
#print(round(mean_score))

# Сколько студентов получили 0 баллов по математике?
#print(student_data[(student_data['math score'] == 0)].shape[0])

# Проверьте гипотезу: у студентов с оплачиваемым питанием средний балл по математике выше, чем у студентов с льготным питанием.
# В качестве ответа напишите наибольший средний балл по математике среди этих групп студентов.
#mean_score_launch_st = student_data[(student_data['lunch'] == 'standard')]['math score'].mean()    
#mean_score_launch_fr = student_data[(student_data['lunch'] == 'free/reduced')]['math score'].mean()

#print(f'st = {round(mean_score_launch_st)}, fr = {round(mean_score_launch_fr)}') 

# Каков процент студентов, родители которых имеют высшее образование уровня бакалавриата (bachelor's degree)?  
#parent_lvl_bach = student_data[(student_data['parental level of education'] ==  "bachelor's degree")].shape[0]
#parent_lvl = student_data['parental level of education'].shape[0]
#procent_lvl = round((parent_lvl_bach / parent_lvl) * 100)
#print(parent_lvl_bach, parent_lvl, procent_lvl)

# Насколько медианный балл по письму у студентов в расовой группе А отличается от среднего балла по письму у студентов в расовой группе C?

median_writing_A = student_data[(student_data['race/ethnicity'] == 'group A')]['writing score'].median()
mean_writing_C = student_data[(student_data['race/ethnicity'] == 'group C')]['writing score'].mean()
print(round(median_writing_A), round(mean_writing_C))
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
